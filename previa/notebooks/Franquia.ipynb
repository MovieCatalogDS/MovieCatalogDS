# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url_film_series = 'https://en.wikipedia.org/wiki/Film_series'
response = requests.get(url_film_series)
print(response.text)

# %%
html_doc = response.text
soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())

# %%
table = soup.find('table')
print(type(table))
rows = table.find_all('tr')

# %%
print(rows[0])
for row in rows:
  cols = row.find_all('td')
  print(cols)

# %%
film_series = pd.read_html(response.text)[0]
print(film_series.columns)
# Out:
# Index(['#', 'Franchise', 'Total gross', 'Movie count', 'Highest-grossing film',
#        'Gross', 'First'],
#       dtype='object')

# %%
for franchise in film_series['Franchise']:
  print(franchise)

# %%
franchises = film_series[['#','Franchise', 'Movie count']]
franchises.columns = ['id', 'nome', 'num_filmes']

franchises.to_csv('franquia.csv', index=False, encoding='utf-8')
